# %%
import os
from phathom import io

# %%
working_dir = '/media/jswaney/Drive/Justin/organoid_etango'

# %%
arr_syto = io.zarr.open(os.path.join(working_dir, 'syto16_clahe.zarr/4_4_4'))
arr_syto.shape
# Out:
# (160, 1106, 1106)

# %%
plt.figure()
plt.imshow(arr_syto[128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
