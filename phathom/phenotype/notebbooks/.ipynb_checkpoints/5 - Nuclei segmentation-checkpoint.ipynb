# %%
import os
import numpy as np
from phathom import io
from phathom.preprocess import filtering
from phathom.segmentation import graphcuts

from phathom import plotting

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportWarning                             Traceback (most recent call last)
# <ipython-input-1-16d6c807eb47> in <module>()
#       5
#       6 from phathom.segmentation import graphcuts
# ----> 7 from phathom.preprocess import filtering
#       8 from phathom import plotting
#       9
#
# ~/phathom/phathom/preprocess/filtering.py in <module>()
#       9 import numpy as np
#      10 from skimage.exposure import equalize_adapthist
# ---> 11 from skimage.filters import gaussian
#      12 import tqdm
#      13 from phathom import io
#
# ~/anaconda3/envs/phathom/lib/python3.6/site-packages/skimage/filters/__init__.py in <module>()
#       1 from .lpi_filter import inverse, wiener, LPIFilter2D
#       2 from ._gaussian import gaussian
# ----> 3 from .edges import (sobel, sobel_h, sobel_v,
#       4                     scharr, scharr_h, scharr_v,
#       5                     prewitt, prewitt_h, prewitt_v,
#
# ~/anaconda3/envs/phathom/lib/python3.6/site-packages/skimage/filters/edges.py in <module>()
#      15 from scipy.ndimage import convolve, binary_erosion, generate_binary_structure
#      16
# ---> 17 from ..restoration.uft import laplacian
#      18
#      19 EROSION_SELEM = generate_binary_structure(2, 2)
#
# ~/anaconda3/envs/phathom/lib/python3.6/site-packages/skimage/restoration/__init__.py in <module>()
#       6 from .deconvolution import wiener, unsupervised_wiener, richardson_lucy
#       7 from .unwrap import unwrap_phase
# ----> 8 from ._denoise import (denoise_tv_chambolle, denoise_tv_bregman,
#       9                        denoise_bilateral, denoise_wavelet, estimate_sigma)
#      10 from ._cycle_spin import cycle_spin
#
# ~/anaconda3/envs/phathom/lib/python3.6/site-packages/skimage/restoration/_denoise.py in <module>()
#       4 from math import ceil
#       5 from .. import img_as_float
# ----> 6 from ..restoration._denoise_cy import _denoise_bilateral, _denoise_tv_bregman
#       7 from .._shared.utils import skimage_deprecation, warn
#       8 import pywt
#
# skimage/restoration/_denoise_cy.pyx in init skimage.restoration._denoise_cy()
#
# ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__

# %%
# %matplotlib notebook

# %%
working_dir = '/media/jswaney/Drive/Justin/organoid_etango/'

# %% [markdown]
# # Foreground mask graph cuts

# %%
syto16_path = 'syto16_test2.zarr'

syto16 = io.zarr.open(os.path.join(working_dir, syto16_path))
syto16.shape, syto16.dtype
# Out:
# ((256, 512, 512), dtype('uint16'))

# %%
syto16_smooth_path = 'syto16_test2_smooth.zarr'

syto16_smooth = io.zarr.new_zarr_like(os.path.join(working_dir, syto16_smooth_path), syto16)
syto16.shape, syto16.dtype
# Out:
# ((256, 512, 512), dtype('uint16'))

# %%
foreground_path = 'foreground.zarr'

foreground = io.zarr.new_zarr(os.path.join(working_dir, foreground_path), 
                              syto16.shape, 
                              syto16.chunks, 
                              np.uint8)

# %%
overlap = 8
chunks = (128, 128, 128)
nb_workers = 12
kwargs = {'back_mu': 400,
          'obj_mu': 4000,
          'w_const': 0}

graphcuts.parallel_graph_cuts(syto16, foreground, overlap, chunks, nb_workers, **kwargs)
# Out:
# 100%|██████████| 32/32 [00:01<00:00, 17.96it/s]

# %%
plt.imshow(syto16[8])
plt.imshow(foreground[8], alpha=0.4, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
prob_path = 'nuclei_probability.zarr'

prob = io.zarr.open(os.path.join(working_dir, prob_path))
prob.shape
# Out:
# (256, 512, 512)

# %%
# Out:
# array([[0.13338251, 0.13636865, 0.12722458, ..., 0.15545794, 0.1440278 ,
#         0.1390442 ],
#        [0.11440986, 0.1171522 , 0.10921413, ..., 0.1690992 , 0.16067189,
#         0.15483208],
#        [0.09160364, 0.09260284, 0.08499387, ..., 0.1569508 , 0.1587686 ,
#         0.15822428],
#        ...,
#        [0.0104649 , 0.01293552, 0.02491042, ..., 0.00356644, 0.00714765,
#         0.0093631 ],
#        [0.02375391, 0.02695406, 0.05045769, ..., 0.00323796, 0.00615045,
#         0.00743815],
#        [0.04049958, 0.04057378, 0.070288  , ..., 0.00348427, 0.00624624,
#         0.00695865]], dtype=float32)
