# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from phathom.phenotype import celltype
from phathom import io
from phathom import utils
from phathom import plotting

# %%
# %matplotlib inline

# %%
working_dir = '/home/jswaney/org_registration'

# %% [markdown]
# # Set parameters on test images

# %%
syto16_path = 'round1/syto16.zarr/1_1_1'

syto16_zarr = io.zarr.open(os.path.join(working_dir, syto16_path))
syto16_zarr.shape
# Out:
# (578, 2362, 2840)

# %%
# extract test patch
shape = np.array((32, 256, 256))
start = np.array((200, 512, 512))

stop = start + shape

syto16_test = utils.extract_box(syto16_zarr, start, stop)
syto16_test.shape
# Out:
# (32, 256, 256)

# %%
plt.imshow(syto16_test[16])
plt.show()

# %%
sigma = (1.0, 2.5, 2.5)
steepness = 4000
offset = -0.0001

prob = celltype.nucleus_probability(syto16_test, sigma, steepness, offset)

# %%
plt.figure(figsize=(4, 4))
plt.imshow(prob[16], clim=[0, 1])
plt.show()

# %%
prob_path = 'round1/nuclei_probability.zarr'

prob_output = io.zarr.new_zarr(os.path.join(working_dir, prob_path), 
                               syto16_zarr.shape, 
                               syto16_zarr.chunks,
                               np.float32)

results = celltype.detect_nuclei_parallel(syto16_zarr, 
                                          sigma=(1.0, 2.5, 2.5), 
                                          min_intensity=400,
                                          steepness=steepness, 
                                          offset=offset,
                                          prob_thresh=0.1,
                                          min_dist=2,
                                          chunks=(64, 128, 128),
                                          overlap=0,
                                          nb_workers=1,
                                          prob_output=prob_output)
centers_list = [r for r in results if r is not None]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-c2356f84d7d2> in <module>
#      16                                           overlap=0,
#      17                                           nb_workers=1,
# ---> 18                                           prob_output=prob_output)
#      19 centers_list = [r for r in results if r is not None]
#
# ~/phathom/phathom/phenotype/celltype.py in detect_nuclei_parallel(z_arr, sigma, min_intensity, steepness, offset, prob_thresh, min_dist, chunks, overlap, nb_workers, prob_output)
#     191                 min_dist=min_dist,
#     192                 prob_output=prob_output)
# --> 193     results = utils.pmap_chunks(f, z_arr, chunks, nb_workers, use_imap=True)
#     194     return results
#     195
#
# ~/phathom/phathom/utils.py in pmap_chunks(f, arr, chunks, nb_workers, use_imap)
#     296     else:
#     297         if use_imap:
# --> 298             results = list(tqdm.tqdm(map(f, args_list), total=len(args_list)))
#     299         else:
#     300             results = list(starmap(f, args_list))
#
# ~/anaconda3/envs/phathom/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     977 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     978
# --> 979             for obj in iterable:
#     980                 yield obj
#     981                 # Update and possibly print the progressbar.
#
# ~/phathom/phathom/phenotype/celltype.py in _detect_nuclei_chunk(input_tuple, overlap, sigma, min_intensity, steepness, offset, prob_thresh, min_dist, prob_output)
#     158         return None
#     159
# --> 160     prob = nucleus_probability(ghosted_chunk, sigma, steepness, offset)
#     161
#     162     if prob_output is not None:
#
# ~/phathom/phathom/phenotype/celltype.py in nucleus_probability(image, sigma, steepness, offset)
#     125     """
#     126     g = smooth(image, sigma)
# --> 127     eigvals = calculate_eigvals(g)
#     128     p_curvature = curvature_probability(eigvals, steepness, offset)
#     129     p_intensity = intensity_probability(g)
#
# ~/phathom/phathom/phenotype/celltype.py in calculate_eigvals(g)
#      39
#      40 def calculate_eigvals(g):
# ---> 41     eigvals = eigvals_of_weingarten(g)
#      42     return eigvals
#      43
#
# ~/phathom/phathom/segmentation/torch_impl.py in eigvals_of_weingarten(x, ew_block_size, zum, yum, xum)
#     336                               zip(to_gpu[1:], eow[1:], from_gpu[:-1])), []) +\
#     337                      [from_gpu[-1]]
# --> 338         [_() for _ in operations]
#     339     finally:
#     340         logging.debug("Deleting intermediate variables")
#
# ~/phathom/phathom/segmentation/torch_impl.py in <listcomp>(.0)
#     336                               zip(to_gpu[1:], eow[1:], from_gpu[:-1])), []) +\
#     337                      [from_gpu[-1]]
# --> 338         [_() for _ in operations]
#     339     finally:
#     340         logging.debug("Deleting intermediate variables")
#
# ~/phathom/phathom/segmentation/torch_impl.py in <lambda>(x0a, x1a, y0a, y1a, z0a, z1a, idx)
#     324                 lambda x0a=x0a, x1a=x1a, y0a=y0a, y1a=y1a, z0a=z0a, z1a=z1a,
#     325                        idx=idx:
# --> 326                        do_copy_to_gpu(x0a, x1a, y0a, y1a, z0a, z1a, idx))
#     327             eow.append(lambda idx=idx: do_eigenvalues_of_weingarten(idx))
#     328             from_gpu.append(
#
# ~/phathom/phathom/segmentation/torch_impl.py in do_copy_to_gpu(x0a, x1a, y0a, y1a, z0a, z1a, idx)
#     292                           (x0a, x1a, y0a, y1a, z0a, z1a, idx))
#     293             a[idx] = torch.from_numpy(
# --> 294                 xpad[z0a:z1a + 4, y0a:y1a + 4, x0a:x1a + 4]).cuda()
#     295             logging.debug("Finished copy to GPU: %d:%d, %d:%d, %d:%d idx=%d" %
#     296                           (x0a, x1a, y0a, y1a, z0a, z1a, idx))
#
# RuntimeError: sizes must be non-negative

# %%
plt.imshow(prob_output[21])  # check that the probability map was saved properly
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import tifffile

# %%
tifffile.imsave(os.path.join(working_dir, 'prob_map.tif'), prob_output[21].astype(np.float32))

# %%
tifffile.imsave(os.path.join(working_dir, 'nuclei_img.tif'), syto16_zarr[21])

# %%
centers = np.vstack(centers_list)
centers.shape
# Out:
# (60196, 3)

# %%
plt.figure(figsize=(4, 4))
plotting.zprojection(syto16_zarr, centers, zlim=[18, 26])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from phathom.synthetic import points_to_binary

# %%
centers_img = points_to_binary(tuple(centers.T), syto16_zarr.shape)

# %%
tifffile.imsave(os.path.join(working_dir, 'centers.tif'), centers_img)

# %%
plotting.plot_pts(centers, alpha=0.01)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# # Save the nuclei centers

# %%
centers_path = 'centers.npy'

np.save(os.path.join(working_dir, centers_path), centers)

# %%
data = tifffile.imread(os.path.join(working_dir, 'syto16.tif'))

# %%
data.shape
# Out:
# (638, 4424, 4422)

# %%
h = plt.hist(data.flatten(), bins=256, range=[0, 4095])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
