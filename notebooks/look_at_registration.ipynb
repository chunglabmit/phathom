# %%
import os
import matplotlib.pyplot as plt
from phathom import io

# %%
working_dir = '/home/jswaney/coregistration'

# %%
fixed_path = 'fixed/zarr_stack/1_1_1'
reg_path = 'moving/registered6/1_1_1'

fixed_img = io.zarr.open(os.path.join(working_dir, fixed_path), mode='r')
reg_img = io.zarr.open(os.path.join(working_dir, reg_path), mode='r')

# %%
zslice = 1000

fixed_slice = fixed_img[zslice]
reg_slice = reg_img[zslice]

# %%
# %matplotlib notebook

plt.figure(figsize=(6, 6))
plt.imshow(fixed_slice, cmap='Reds', clim=[0, 3000])
plt.imshow(reg_slice, cmap='Greens', clim=[0, 1500], alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
