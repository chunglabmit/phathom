# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

plt.ion()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
# Training dataset
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST(root='.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])), batch_size=64, shuffle=True, num_workers=4)
# Test dataset
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST(root='.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])), batch_size=64, shuffle=True, num_workers=4)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

        # Spatial transformer localization-network
        self.localization = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 3 * 3, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 3 * 3)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)

        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)

        return x

    def forward(self, x):
        # transform the input
        x = self.stn(x)

        # Perform the usual forward pass
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


model = Net().to(device)

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 500 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
#
# A simple test procedure to measure STN the performances on MNIST.
#


def test():
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)

            # sum up batch loss
            test_loss += F.nll_loss(output, target, size_average=False).item()
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'
              .format(test_loss, correct, len(test_loader.dataset),
                      100. * correct / len(test_loader.dataset)))

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# We want to visualize the output of the spatial transformers layer
# after the training, we visualize a batch of input images and
# the corresponding transformed batch using STN.


def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        data = next(iter(test_loader))[0].to(device)

        input_tensor = data.cpu()
        transformed_input_tensor = model.stn(data).cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2)
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')


for epoch in range(1, 20 + 1):
    train(epoch)
    test()

# Visualize the STN transformation on some input batch
visualize_stn()

plt.ioff()
plt.show()
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.347858
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.911679
#
# Test set: Average loss: 0.2502, Accuracy: 9287/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.476891
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.238354
#
# Test set: Average loss: 0.1702, Accuracy: 9503/10000 (95%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.377553
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.330411
#
# Test set: Average loss: 0.0940, Accuracy: 9699/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.199911
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.154851
#
# Test set: Average loss: 0.0824, Accuracy: 9740/10000 (97%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.279968
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.175927
#
# Test set: Average loss: 0.0745, Accuracy: 9752/10000 (98%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.338134
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.165522
#
# Test set: Average loss: 0.0714, Accuracy: 9763/10000 (98%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.054805
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.345291
#
# Test set: Average loss: 0.0631, Accuracy: 9797/10000 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.110852
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.078543
#
# Test set: Average loss: 0.0590, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.132860
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.165038
#
# Test set: Average loss: 0.0670, Accuracy: 9801/10000 (98%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.100072
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.144293
#
# Test set: Average loss: 0.0615, Accuracy: 9817/10000 (98%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.133921
# Train Epoch: 11 [32000/60000 (53%)]	Loss: 0.090869
#
# Test set: Average loss: 0.0498, Accuracy: 9854/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.143009
# Train Epoch: 12 [32000/60000 (53%)]	Loss: 0.085002
#
# Test set: Average loss: 0.0477, Accuracy: 9846/10000 (98%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.056331
# Train Epoch: 13 [32000/60000 (53%)]	Loss: 0.101980
#
# Test set: Average loss: 0.0462, Accuracy: 9865/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.244041
# Train Epoch: 14 [32000/60000 (53%)]	Loss: 0.108087
#
# Test set: Average loss: 0.0645, Accuracy: 9801/10000 (98%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.289085
# Train Epoch: 15 [32000/60000 (53%)]	Loss: 0.068199
#
# Test set: Average loss: 0.0478, Accuracy: 9846/10000 (98%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.095700
# Train Epoch: 16 [32000/60000 (53%)]	Loss: 0.055337
#
# Test set: Average loss: 0.0432, Accuracy: 9858/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.085619
# Train Epoch: 17 [32000/60000 (53%)]	Loss: 0.061261
#
# Test set: Average loss: 0.0939, Accuracy: 9711/10000 (97%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.191511
# Train Epoch: 18 [32000/60000 (53%)]	Loss: 0.043569
#
# Test set: Average loss: 0.0443, Accuracy: 9854/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.039579
# Train Epoch: 19 [32000/60000 (53%)]	Loss: 0.052510
#
# Test set: Average loss: 0.0438, Accuracy: 9871/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.020588
# Train Epoch: 20 [32000/60000 (53%)]	Loss: 0.075120
#
# Test set: Average loss: 0.0454, Accuracy: 9854/10000 (99%)

# %%
n = 10
x = np.arange(100).reshape((1, 1, 10, 10))
grid = np.random.rand(1, n, n, 2)
x = torch.from_numpy(x).float()
grid = torch.from_numpy(grid).float()
x = F.grid_sample(x, grid)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-2e4965420586> in <module>()
#       4 x = torch.from_numpy(x).float()
#       5 grid = torch.from_numpy(grid).float()
# ----> 6 x = F.grid_sample(x, grid)
#
# ~/anaconda3/envs/phathom/lib/python3.5/site-packages/torch/nn/functional.py in grid_sample(input, grid, mode, padding_mode)
#    1861
#    1862     """
# -> 1863     return vision.grid_sampler(input, grid, padding_mode)
#    1864
#    1865
#
# ~/anaconda3/envs/phathom/lib/python3.5/site-packages/torch/nn/_functions/vision.py in grid_sampler(input, grid, padding_mode)
#      14         return torch.cudnn_grid_sampler(input, grid)
#      15     else:
# ---> 16         return GridSampler.apply(input, grid, padding_mode)
#      17
#      18
#
# ~/anaconda3/envs/phathom/lib/python3.5/site-packages/torch/nn/_functions/vision.py in forward(ctx, input, grid, padding_mode)
#      51             output = input.new(grid_sz[0], input.size(1), grid_sz[1], grid_sz[2])
#      52             backend.SpatialGridSamplerBilinear_updateOutput(backend.library_state, input, grid,
# ---> 53                                                             output, ctx.padding_mode)
#      54         elif input.dim() == 5:
#      55             output = input.new(grid_sz[0], input.size(1), grid_sz[1], grid_sz[2], grid_sz[3])
#
# RuntimeError: Need grid of dimension 4 and grid.size[3] == 2 but got grid to be of shape: [1 x 1 x 10 x 10] at /opt/conda/conda-bld/pytorch_1524580978845/work/aten/src/THNN/generic/SpatialGridSamplerBilinear.c:26
